# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pantelis-nlp/tutorial-nlp-notebooks/blob/main/rnn_language_model.ipynb)

# %%
#data to train on
data = 'Chios island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mountains running the length of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island. The center of the island is divided between east and west by a range of smaller peaks, known as Provatas.'

# %%
#import necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, Model
import time 
 
"""
General Idea:
We will train our model with a list of strings encoded in one-hot and a list of target indices corresponding 
to the character that follows up each string. The length of each string will be defined by num_chars, and the length of 
the resulting list will be dependent on the number of characters we choose to extract: seq_length. The result will be a 
seq_length / num_chars 3D array consisting of (num_examples = int(seq_length / num_chars), num_chars, vocab_size)

The exact details of the model will be defined in a later cell. 
"""
#get a list of all characters used in the data
chars = list(set(data))

#define the size of our data and vocabulary
data_size, vocab_size = len(data), len(chars)

print('data has %d characters, %d unique.' % (data_size, vocab_size))

#create mappings of character to index and from index to character
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }


#length of text to extract
seq_length = 200

#define number of characters to extract per string
num_chars = 7
# Out:
# data has 508 characters, 43 unique.

# %%
#perform one hot encoding of a list of strings
def one_hot_encoding(lst):
    #define list to store encoded slices of text
    X = []
    #go through every string in list
    for string in lst:
        #keep list of encoding per character
        encoding = []
        for char in string:
          #encode character in one-hot
          row = np.zeros((1,vocab_size))
          row[0][char_to_ix[char]] = 1
          #add to our encoding list
          encoding.append(row)
        #add our encoded string to X
        X.append(encoding)
    #convert to np array    
    X = np.array(X)
    
    #reshape to match our input shape for network
    X = X.reshape(X.shape[0], X.shape[1], X.shape[3])
    return X

# %%
  #returns an input and output vector to fit model with
  def variable_input_output(p,n, seq_length):
    '''
    inputs:
    p : starting point index to extract characters from
    seq_length : how many characters from starting point to extract
    n : how many characters to extract per skip
    '''
    #input (X) vector, list of strings of n length
    input = [data[i:i+n] for i in range(p,p+seq_length, n)]
    #target (Y) vector, list of characters that follow the strings in input
    target = [data[i+n-1:i+n] for i in range(p+1, p+seq_length+1 , n)]
    
    return input, target

# %%
"""
The model will follow the pipeline

Input of shape (num_chars, vocab_size)

This input will be convolved with 3 different 1D convolutions:
  10 filters of kernel size 2 -> output shape (num_chars - 1, 10)
  10 filters of kernel size 3 -> output shape (num_chars - 2, 10)
  10 filters of kernel size 4 -> output shape (num_chars - 3, 10)

These filters will be concatenated together along axis 1 to get a shape of (3*num_chars - 6, 10)

The concatenation of this will be passed into a MaxPooling1D layer with same padding and have output shape (int((3*num_chars - 6)/2), 10)

The result will be flattened into shape (None, (3*num_chars - 6)/2) * 10)

Finally, this will be passed into a FC with a softmax of size vocab_size of shape (None, vocab_size)

The idea behind this model is to be able to train on different inputs and possible contexts of words. This is why we use 10 filters per convolution, so we can capture
all potential contexts that the kernel is capturing. Three different convolutions are also used so the model can have more information based on every 2, 3, and 4 characters
of each encoded string. This is why we use 3 convolutions of different filter sizes and concatenate them all later on. 

"""
#define our input of shape (num_chars, vocab_size)
input_ = layers.Input(shape = (num_chars, vocab_size))

#run 3 different convolutions on it with different sizes and activation relu
conv1 = layers.Conv1D(10, (2), activation='relu')(input_)
conv2 = layers.Conv1D(10, (3), activation='relu')(input_)
conv3 = layers.Conv1D(10, (4), activation='relu')(input_)

#concatenate our different convolution results
concat = layers.concatenate([conv1,conv2,conv3], axis = 1)

#perform max pooling on our concatenation
pool = layers.MaxPooling1D(padding  = "same")(concat)

#flatten it 
flat = layers.Flatten()(pool)

#pass into FC and use softmax to get probabilities
final = layers.Dense(vocab_size, activation='softmax')(flat)

#create our model
model = Model(inputs=[input_], outputs=[final])

#generate a moodel summary
model.summary()

#compile our model with loss as categorical crossentropy
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 7, 43)]      0           []
#
#  conv1d_3 (Conv1D)              (None, 6, 10)        870         ['input_2[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 5, 10)        1300        ['input_2[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 4, 10)        1730        ['input_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 15, 10)       0           ['conv1d_3[0][0]',
#                                                                   'conv1d_4[0][0]',
#                                                                   'conv1d_5[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 8, 10)       0           ['concatenate_1[0][0]']
#
#  flatten_1 (Flatten)            (None, 80)           0           ['max_pooling1d_1[0][0]']
#
#  dense_1 (Dense)                (None, 43)           3483        ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 7,383
# Trainable params: 7,383
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#train our model
def train(num_chars):
  #initialize iter counter and data pointer
  n, p = 0, 0
  #continuously run training for 20 minutes
  end = time.time() + 60 * 20
  while time.time() < end:
    #if we reach end loop again
    if (p+seq_length+1) >= len(data): 
      p = 0 # go from start of data
    
    #fetch input and target with current data pointer, num of characters to extract per training example, and how long the text should be to extract from
    input, target = variable_input_output(p, num_chars, seq_length)
    #if our target hit the end and has no character to follow input, drop last example
    if target[-1] == '':    
      input = input[:-1]
      target = target[:-1]

    #convert our input into a one hot encoded version: of shape (num_examples based on seq_length and num_chars, num_chars, vocab_size)
    X = one_hot_encoding(input)

    #convert our target into a numpy array of char indices
    Y = np.array([char_to_ix[ch] for ch in target])
    
    # evaluate the model at every 100 iterations, extract 200 characters from model
    if n % 100 == 0:
      print("iter {}".format(n))
      #initialize a list that will store sampled indices 
      ixes = []
      #initialize the string that will be used for prediction, at the start this will always be the first num_chars characters of data
      st = [data[0:0+num_chars]]
      #sample 200 indices from model
      for i in range(200):
          #one hot encode our string
          x = one_hot_encoding(st)
          #get softmax prediction from model
          pred = model.predict(x, verbose = 0)
          #using softmax predictions as probabilities, choose an index from the vocab
          ix = np.random.choice(range(vocab_size), p=pred.ravel()) 
          #add it to our indices list 
          ixes.append(ix)
          #reconstruct our string to be 1:num_chars + new indice. So "Chaos Isl" would become "haos Isla" if ix was indice corresponding to "a"
          st[0] = st[0][1:] + ix_to_char[ix]


          
      #create text from sampled indices
      txt = ''.join(ix_to_char[ix] for ix in ixes)
      #print it out
      print('----\n %s \n----' % (txt, ))

    #fit our input and target
    model.fit(X,Y, verbose = 0)

    p += 1 # move data pointer
    n += 1 # iteration counter 

train(num_chars)
print("20 minutes elapsed, training stopped")
# Out:
# iter 0
# ----
#  oe the serren of om, 8t itad iise ituand insd bnd erinean th on (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the oolaae. sh perndewnet peanda wides,, cuveinge of mountain or mou
# ----
# iter 100
# ----
#  untadn the norta kouth, aid aid itudtid it itudtid ins running the length of the islandes of thesi mountainou  and arid, with t daadids widh te covering an area of 842.289 km2 (325.210 sq mi).[2] The
# ----
# iter 200
# ----
#  ount, and 29 km (18 mi) at itse inlane s (mo8 m)1(t, wivest byna range of mountains running the length of the island. Tse mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are si
# ----
# iter 300
# ----
#  ovendng fs mlente soumtarn iie te coverong ane Eeos (1,188 m (3,898 ft)), are situated in the nurtesn buntar on (1,188 m (3,858 ft)), are situateidid oi soutt, divedis povesougtans area it opes alann
# ----
# iter 400
# ----
#  inget on the ioland iss mountain us midnatis, outtaddi5 wi)  ta tar is souat, divided betweeaseamountainous and as diaedt, Pol rainsis on krenna mountains running the length of these mountainous and a
# ----
# iter 500
# ----
#  red bitwe inette of the island. The two largest of the length of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated, kinesa mount
# ----
# iter 600
# ----
#  idean the north of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situa
# ----
# iter 700
# ----
#  outt,, idest by a range of mountains running the length of the island. The center of these mountains running the length of the island is divided between east and west by a range of mountains running t
# ----
# iter 800
# ----
#  untad ou thes arias wistaadids Pidinein (n mm mm29m mi) lont(aron thete wing area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountains, Pelineon (1,297 m (4,255 ft)) and 2p mountains, Pnlineon
# ----
# iter 900
# ----
#  undadn wish al ids cidein the ns arease mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in tee nlangeso of the is maineis mountains, Pelineon (1,297 m (4,255 ft))
# ----
# iter 1000
# ----
#  ol north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountains running the length of the island is covering an area of 842.289 km2 (32
# ----
# iter 1100
# ----
#  oett,, aret it and west ay the island. The two largest of these mountainous and arid, with a ridge of mountains running the length of these mountainous and arid, with a ridge of 8m2. 29e mountains run
# ----
# iter 1200
# ----
#  onet, (ndw89  fatm, nt is divided between east and we kie wo taarids widhs  idland is divided betweenne mountainous and arid, with a ridge of mountainous and arid, with a ridge of mountains, Pelineon
# ----
# iter 1300
# ----
#  idland is miuntains running the length of the island is the island is divided between erra its aidest bhn  rran in miuntains running the length of the island. The cetran ingg of omen8a2h th  is miuntt
# ----
# iter 1400
# ----
#  id.andesTho ttrineit oo kman.a2he kwo largest of these mountains sustaid it deate tse aevang st mountains running the length of the island. The two larg st oler is krins auntain ss mountainous and ari
# ----
# iter 1500
# ----
#  oust, inde nouthand is cidewn thes or aidn aid 2o the island. The center of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the ns ra, ino tf the island.
# ----
# iter 1600
# ----
#  outt, dnd iest by a range of mountainous and arid, with a ridge of mountainous and arid, with a ridge of mountainous and arid, with a ridge of mountainous and arid, with a ridge of mountainous and ari
# ----
# iter 1700
# ----
#  in. thes of the island is crerin on the oomama.2th s rriiseath, solth, sovth, and 29 km (18 mi)tat iss witl aidcess rougtann rwe ns mlunnthg tor amiiustidnd in the tor aidiis it itudtid in the north t
# ----
# iter 1800
# ----
#  untad ou the esngta of these mountannou aong ane is mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the nouth, and 29 km (18 mi) at its widest, covering an area
# ----
# iter 1900
# ----
#  inst Peoitaand weit ot lin. the center of these mountainous and arid, with a ridge of mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north to south, and 29
# ----
# iter 2000
# ----
#  mllnd ith te cins arnd in the northg of mountains running the length of these mountains running the length of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated
# ----
# iter 2100
# ----
#  nd aenderro on the north in sn, aol naid aiddes ith te ridg oo marnd, Toe the length of the island. The terrain is mountains, Pelineon (1,297 mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m
# ----
# iter 2200
# ----
#  outt, of the island is cretcet or kidney shaped, 50 km (31 mi) long from north to south, ande29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous
# ----
# iter 2300
# ----
#  id,arid in the north to south, and 29 km (18 mi).at] The terrain is mountainous and arid, with a ridge of mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the no
# ----
# iter 2400
# ----
#  ideatit of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in is mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the
# ----
# iter 2500
# ----
#  undann the oenthe of the island. The center of the island. The two largest of the island. The center of the island is crevcent rrad in the north of the island. The two largest of the island is krene t
# ----
# iter 2600
# ----
#  alit, with a ridge of mountainous and arid, with a ridge of mountainous and. rid in the north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain
# ----
# iter 2700
# ----
#  sland. The two largest of the island. The censerron tf south, and 29 km (18 mi) ao th aids, Pelineon (1,297 m (4,255 ft)) and Epos (1, 8e msua8eds (1pds 5ided of the island is divided between east and
# ----
# iter 2800
# ----
#  sl kd. the certes of the island is crescent or kidneris and we ter ain is mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north to south, and 29 km (18 mi)
# ----
# iter 2900
# ----
#  inest bnor rann area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid,8 ftt)eaidest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with
# ----
# iter 3000
# ----
#  undad on the north of the island. The two largest of the island. The two largest of the island. The center of the island. The two largest of the island. The center of the island. The two large ksom ou
# ----
# iter 3100
# ----
#  ridh t eslang is areast and west by a range of the island. The center of the island is divided between east and writ at ids widest, covering an area if 8t2 tous arnowt  sllnde The two largest of the i
# ----
# iter 3200
# ----
#  itge north to south, and 29 km (18 mi)pet its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountains running the length of these mountainous and arid, with a ridge of mou
# ----
# iter 3300
# ----
#  alit of the island. The center of the island. The two largest of the island. The two largest of the island.sThd arriis ountain dren of the island. The center of the island. The two largest of the isla
# ----
# iter 3400
# ----
#  oustarnd we ter ae ter nent, Pol raan area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountains running the length of the island. The center of the island is divided between earta tidse ote cen
# ----
# iter 3500
# ----
#  sland. The two largest of the island. The two largest of the island Epos (1,188 m (3,898 ft)), are situated in the north to south, and 29 km (18 mi) at its witest, covering an area of 842.289 km2 (325
# ----
# iter 3600
# ----
#  uinann th on ridge of mountainous and arid, with a ridge of mountains running the length of the island. The center of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are
# ----
# iter 3700
# ----
#  fland is divided between east and west by a range of smaller peaks, known as Prov,tande roustannous and arid, with a ridge of mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), ar
# ----
# iter 3800
# ----
#  sland. The center of these mountains running the length of the island. The two lsrgest of these mountains running the length of the island. The center of these mountains, Pelineon (1,297 m (4,255 ft))
# ----
# iter 3900
# ----
#  unning the length of these mountains running the length of the island. The two largest of these mountains running the length of these mountains running the length of the island. The two largest of the
# ----
# iter 4000
# ----
#  sland. The center of the island. The center of the island. The center of the island iss and arid, with a ridge of mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated i
# ----
# iter 4100
# ----
#  udnand widh t ridge of mm2.l2n. me(t,29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous and arid, with a ridge of mountains running the length
# ----
# iter 4200
# ----
#  oust, nov Pand 29 km (18 mi) long from north of these mountains running the length of the island., Peoisaand. The two largest of the island. The two largest of these mountains, Pelineon (1,297 m (4,25
# ----
# iter 4300
# ----
#  sland is divided between east and west by a range of smalle tpes s( aed. (12s mountainous and arid, with a ridge of mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated
# ----
# iter 4400
# ----
#  olen th terrin of these mountains running the length of the ioland. The two largest of these mountainous ann the oottaaon the n rras iis arnd, with a ridge of mountains running the length of the islan
# ----
# iter 4500
# ----
#  sllnd. The two largest of the island. The two largest of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north to south
# ----
# iter 4600
# ----
#  sland. The center of the island is divided between eant as divided between east and west by a range of smaller peaks, known as Provita idest, covering an area of 842.289 km2 (325.210 sq mi).[2] The te
# ----
# iter 4700
# ----
#  red between east and west by a range tho trrain is mountains running the length of these mountainous and arid, with a ridge of mountains running the length of the island. The two largest of these moun
# ----
# iter 4800
# ----
#  sland. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north to s area to south, ande29  mal8trt ins arid, with a ridge of mountain
# ----
# iter 4900
# ----
#  oust, dnvers  ind arid, with a ridge of mountainous and arid, with ae the nsrano  wontaa of 842.289 km2 (325.210 sq mi).[2] The terrainous and arid, with a ridge of mountains, Pelineon (1,297 m (4,255
# ----
# iter 5000
# ----
#  sland is crenceng north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountains running the length of the island is cretcen or aoustapoi
# ----
# iter 5100
# ----
#  sland. The two largest of these mountains running the length of the island. The two largest of these mountains running the length of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3
# ----
# iter 5200
# ----
#  sland. The center of the island. The center of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island. The center of these mountains, Pel
# ----
# iter 5300
# ----
#  outh, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountains running the length of these mountainous and arid, with a ridge of mountainous and ar
# ----
# iter 5400
# ----
#  sland. The two largest of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north to south, and 29 km (18 mi) at its wide
# ----
# iter 5500
# ----
#  slind arnd, with a ridge of mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north of the island is divided between east and west by a range of smaller peaks
# ----
# iter 5600
# ----
#  sland is cretcet on the north of the island. The center of the island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at its widest, covering an area of 842.289
# ----
# iter 5700
# ----
#  sland. The two largest of the island. The two largest of these mountains running the length of these mountainous and arid, with a ridge of mountains running the length of these mountainous and arid, w
# ----
# iter 5800
# ----
#  sl nd is divided between east and west by a rang an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the n
# ----
# iter 5900
# ----
#  sland. The center of the island is divided between east and west by a range of smaller peaks, kn wn ks, rov tang are ait as area tt 8nd  Pidiaedt, covering an area of 842.289 km2 (325.210 sq mi).[2] T
# ----
# iter 6000
# ----
#  sland. The center of the island. The two largest of these mountainous and arid, with a ridge of mountains running the length of the island. The two largest of these mountains, Pelineon (1,297 m (4,255
# ----
# iter 6100
# ----
#  sland is divided between east and west by a range of smaller peaks, known as Provatas. 8s mavneri soa taidearo  n4alea of 842.289 km2 (325.210 sq mi).[2] The terrain is mountains, Pelineon (1,297 m (4
# ----
# iter 6200
# ----
#  sland is crescett on the north to south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m
# ----
# iter 6300
# ----
#  sland. The two largest of the island. The two largest of the island. The two largest of these mountains running the length of the island. The two largest of these mountains, Pelineon (1,297 m (4,255 f
# ----
# iter 6400
# ----
#  sland. The two largest of the island is divided between east and west by a range of smallen peaks, known as Provaiids widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountai
# ----
# iter 6500
# ----
#  sland is divided between east and west by a range of smaller peaks, known as Prouatains running the length of the island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km
# ----
# iter 6600
# ----
#  st and west by a range of these mountains running the length of the island. The two largest of these mountainous and arid, with a ridge of mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3
# ----
# iter 6700
# ----
#  sland. The center of the island is divided between east and wesc by s (n,8 mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north ti south, and 29 km (18 mi)
# ----
# iter 6800
# ----
#  outh, and 29 km (18 mi) at its widest, coverrng tf south, and 29 km (18 mi) at its widest, covering an area of 842.289 km2 (325.210 sq mi).[2] The ter ain is mountains running the length of the island
# ----
# iter 6900
# ----
#  sland. The two largest of the island. The two largest of these mountainous and arid, with a ridge of mountains, Pelineon (1,297 m (4,255 ft)) and Epos (1,188 m (3,898 ft)), are situated in the north t
# ----
# iter 7000
# ----
#  slind. The two largest of the island is divided between east and west by a range of smaller peaks, known as Provatao of the island. The two largest of the island. The two largest of nmas orot of these
# ----
# iter 7100
# ----
#  untan ou the island is crescent or kidney shaped, 50 km (31 mi) long from north to south, and 29 km (18 mi) at i3s win the north t on area of 842.289 km2 (325.210 sq mi).[2] The terrain is mountainous
# ----
# 20 minutes elapsed, training stopped
